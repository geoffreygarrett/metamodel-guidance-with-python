# %% [markdown]
# # Network Architecture

# %% [markdown]
# ## ResNet block
#
# - http://www.kaytek.co.in/ai/8H31_Kaytek_Residual_Block_Explanation.pdf

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://miro.medium.com/max/896/1*ueFv8cl-d76ibX_elWNhcQ.jpeg", width=800, height=100)
# Out:
# <img src="https://miro.medium.com/max/896/1*ueFv8cl-d76ibX_elWNhcQ.jpeg" width="800" height="100"/>

# %%
# %cd '/home/ggarrett/lab/NB10422645 (Stage - Airbus)/'
# Out:
# /home/ggarrett/lab/NB10422645 (Stage - Airbus)

# %%
tab=[[  1 , 0.977810 ,0.675483],
[ 2  , 0.572126 ,0.439709],
[ 3  , 0.374533 ,0.290304],
[ 4  , 0.248037 ,0.192683],
[ 5  , 0.164904 ,0.128243],
[ 6  , 0.109819 ,0.085618],
[ 7  , 0.073416 ,0.057349],
[ 8  , 0.049288 ,0.038603],
[ 9  , 0.033199 ,0.026135],
[10  , 0.022579 ,0.017855],
[11  , 0.015475 ,0.012347],
[12  , 0.010801 ,0.008674],
[13  , 0.007613 ,0.006234],
[14  , 0.005526 ,0.004597],
[15  , 0.004138 ,0.003501],
[16  , 0.003188 ,0.002763],
[17  , 0.002560 ,0.002269],
[18  , 0.002127 ,0.001931],
[19  , 0.001839 ,0.001699],
[20  , 0.001636 ,0.001540],
[21  , 0.001498 ,0.001425],
[22  , 0.001394 ,0.001345],
[23  , 0.001319 ,0.001282],
[24  , 0.001270 ,0.001233],
[25  , 0.001215 ,0.001198],
[26  , 0.001188 ,0.001167],
[27  , 0.001158 ,0.001142],
[28  , 0.001134 ,0.001121],
[29  , 0.001120 ,0.001101],
[30  , 0.001094 ,0.001085],
[31  , 0.001084 ,0.001067],
[32  , 0.001075 ,0.001050],
[33  , 0.001050 ,0.001035],
[34  , 0.001039 ,0.001021],
[35  , 0.001025 ,0.001010],
[36  , 0.001010 ,0.000994],
[37  , 0.000996 ,0.000981],
[38  , 0.000978 ,0.000968],
[39  , 0.000962 ,0.000957],
[40  , 0.000964 ,0.000949],
[41  , 0.000941 ,0.000935],
[42  , 0.000934 ,0.000926],
[43  , 0.000920 ,0.000914],
[44  , 0.000914 ,0.000904],
[45  , 0.000900 ,0.000895],
[46  , 0.000897 ,0.000883],
[47  , 0.000884 ,0.000875],
[48  , 0.000872 ,0.000865],
[49  , 0.000860 ,0.000853],
[50  , 0.000850 ,0.000847],
[51  , 0.000851 ,0.000839],
[52  , 0.000834 ,0.000829],
[53  , 0.000831 ,0.000823]]

tab = np.array(tab)

import matplotlib.pyplot as plt
# %matplotlib inline

print(tab.shape)
tab=tab[:,:]

plt.figure(figsize=(5,5), dpi=300)
plt.plot(tab[:,0], tab[:,1], label="Train loss")
plt.plot(tab[:,0], tab[:,2], label="Test loss")
plt.legend()
plt.show()
# Out:
# (53, 3)
